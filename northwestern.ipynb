# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np

northwestern_df = pd.read_excel('./northwestern_data.xlsx')
northwestern_df.head()
# Out:
#          Case ID#              Filed: Status:                      Court:  \
# 0  \n19-10-160319 2019-10-15 00:00:00  Closed  Northampton District Court
# 1  \n19-10-160319 2019-10-15 00:00:00  Closed  Northampton District Court
# 2               0 2008-05-07 00:00:00  Closed   Greenfield District Court
# 3               0 2008-05-07 00:00:00  Closed   Greenfield District Court
# 4    00-03-111111 2001-10-17 14:32:14  Closed                          DC
#
#   Gender:  Race:       Ethnicity: Crime Type:  Count:      Charge Code:  ...  \
# 0    Male  White  Hispanic/Latinx    Assaults       1         265/15B/A  ...
# 1    Male  White  Hispanic/Latinx    Assaults       2         265/13A/B  ...
# 2  Female  White              NaN    Assaults       1         265/13A/B  ...
# 3  Female  White              NaN    Assaults       2           268/32B  ...
# 4    Male    NaN              NaN         OUI       1  OP UNDR INFL LIQ  ...
#
#   Prosecutor Facility: Prosecutor Sentence Type: Prosecutor Term Min:  \
# 0                  NaN                       NaN                  NaN
# 1                  NaN                       NaN                  NaN
# 2                  NaN                       NaN                  NaN
# 3                  NaN                       NaN                  NaN
# 4                  NaN                       NaN                  NaN
#
#   Prosecutor Term Min Unit: Prosecutor Term Max: Prosecutor Term Max Unit:  \
# 0                       NaN                  NaN                       NaN
# 1                       NaN                  NaN                       NaN
# 2                       NaN                  NaN                       NaN
# 3                       NaN                  NaN                       NaN
# 4                       NaN                  NaN                       NaN
#
#   Fine: Probation: Probation Term: Probation Term Unit:
# 0   NaN        NaN             NaN                  NaN
# 1   NaN  Probation             2.0                Years
# 2   NaN     276/87             1.0                Years
# 3   NaN        NaN             NaN                  NaN
# 4   NaN        NaN             NaN                  NaN
#
# [5 rows x 42 columns]

# %%
df = northwestern_df[['Count:', "Charge Description:" ,"Crime Type:", "Race:", "Gender:", "Disposition:", "Sentence Type:"]]
# df.drop()
#conversion of string/character values to integers
# Ctype = df['Case Type:'].value_counts().index.tolist()
# i = 0
# for i in range(len(Ctype)):
#   df['Case Type:'].replace(Ctype[i], i, inplace = True)
# df['Case Type:']

crime = df['Crime Type:'].value_counts().index.tolist()
i = 0
for i in range(len(crime)):
  df['Crime Type:'].replace(crime[i], i, inplace = True)

j= 0
race = df['Race:'].value_counts().index.tolist()
for j in range(len(race)):
  df['Race:'].replace(race[j], j, inplace = True)

k= 0
sentence = df['Sentence Type:'].value_counts().index.tolist()
for k in range(len(sentence)):
  df['Sentence Type:'].replace(sentence[k], k, inplace = True)

k= 0
disptype = df['Disposition:'].value_counts().index.tolist()
for k in range(len(disptype)):
  df['Disposition:'].replace(disptype[k], k, inplace = True)

k =0
gender = df['Gender:'].value_counts().index.tolist()
for k in range(len(gender)):
  df['Gender:'].replace(gender[k], k, inplace = True)

# k =0
# desc = df['Disp Desc'].value_counts().index.tolist()
# for k in range(len(desc)):
#   df['Disp Desc'].replace(desc[k], k, inplace = True)



# correlation = df["Race"].corr(df["Case Type"])
# correlation
# df['Race']
df2 = df[['Race:', 'Gender:','Crime Type:', 'Disposition:', 'Sentence Type:']]
corr = df2.corr()
corr
corr.style.background_gradient(cmap='coolwarm')
# Out:
# /var/folders/ks/vzxfw4ks2qqgpbl6l3n_3mkr0000gn/T/ipykernel_76438/847649866.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Crime Type:'].replace(crime[i], i, inplace = True)
# /var/folders/ks/vzxfw4ks2qqgpbl6l3n_3mkr0000gn/T/ipykernel_76438/847649866.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Race:'].replace(race[j], j, inplace = True)
# /var/folders/ks/vzxfw4ks2qqgpbl6l3n_3mkr0000gn/T/ipykernel_76438/847649866.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Sentence Type:'].replace(sentence[k], k, inplace = True)
# /var/folders/ks/vzxfw4ks2qqgpbl6l3n_3mkr0000gn/T/ipykernel_76438/847649866.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Disposition:'].replace(disptype[k], k, inplace = True)
# /var/folders/ks/vzxfw4ks2qqgpbl6l3n_3mkr0000gn/T/ipykernel_76438/847649866.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Gender:'].replace(gender[k], k, inplace = True)
# <style type="text/css">
# #T_7d00b_row0_col0, #T_7d00b_row1_col1, #T_7d00b_row2_col2, #T_7d00b_row3_col3, #T_7d00b_row4_col4 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7d00b_row0_col1, #T_7d00b_row3_col1 {
#   background-color: #4358cb;
#   color: #f1f1f1;
# }
# #T_7d00b_row0_col2 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_7d00b_row0_col3, #T_7d00b_row3_col0, #T_7d00b_row4_col0 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_7d00b_row0_col4, #T_7d00b_row1_col0, #T_7d00b_row1_col2, #T_7d00b_row1_col3, #T_7d00b_row2_col1 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_7d00b_row1_col4 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_7d00b_row2_col0 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_7d00b_row2_col3 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_7d00b_row2_col4 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_7d00b_row3_col2, #T_7d00b_row4_col1 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_7d00b_row3_col4 {
#   background-color: #6384eb;
#   color: #f1f1f1;
# }
# #T_7d00b_row4_col2 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_7d00b_row4_col3 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7d00b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7d00b_level0_col0" class="col_heading level0 col0" >Race:</th>
#       <th id="T_7d00b_level0_col1" class="col_heading level0 col1" >Gender:</th>
#       <th id="T_7d00b_level0_col2" class="col_heading level0 col2" >Crime Type:</th>
#       <th id="T_7d00b_level0_col3" class="col_heading level0 col3" >Disposition:</th>
#       <th id="T_7d00b_level0_col4" class="col_heading level0 col4" >Sentence Type:</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7d00b_level0_row0" class="row_heading level0 row0" >Race:</th>
#       <td id="T_7d00b_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_7d00b_row0_col1" class="data row0 col1" >-0.008368</td>
#       <td id="T_7d00b_row0_col2" class="data row0 col2" >-0.002590</td>
#       <td id="T_7d00b_row0_col3" class="data row0 col3" >0.012544</td>
#       <td id="T_7d00b_row0_col4" class="data row0 col4" >0.011472</td>
#     </tr>
#     <tr>
#       <th id="T_7d00b_level0_row1" class="row_heading level0 row1" >Gender:</th>
#       <td id="T_7d00b_row1_col0" class="data row1 col0" >-0.008368</td>
#       <td id="T_7d00b_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_7d00b_row1_col2" class="data row1 col2" >-0.039532</td>
#       <td id="T_7d00b_row1_col3" class="data row1 col3" >-0.009664</td>
#       <td id="T_7d00b_row1_col4" class="data row1 col4" >0.062917</td>
#     </tr>
#     <tr>
#       <th id="T_7d00b_level0_row2" class="row_heading level0 row2" >Crime Type:</th>
#       <td id="T_7d00b_row2_col0" class="data row2 col0" >-0.002590</td>
#       <td id="T_7d00b_row2_col1" class="data row2 col1" >-0.039532</td>
#       <td id="T_7d00b_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_7d00b_row2_col3" class="data row2 col3" >0.065827</td>
#       <td id="T_7d00b_row2_col4" class="data row2 col4" >0.024632</td>
#     </tr>
#     <tr>
#       <th id="T_7d00b_level0_row3" class="row_heading level0 row3" >Disposition:</th>
#       <td id="T_7d00b_row3_col0" class="data row3 col0" >0.012544</td>
#       <td id="T_7d00b_row3_col1" class="data row3 col1" >-0.009664</td>
#       <td id="T_7d00b_row3_col2" class="data row3 col2" >0.065827</td>
#       <td id="T_7d00b_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_7d00b_row3_col4" class="data row3 col4" >0.139413</td>
#     </tr>
#     <tr>
#       <th id="T_7d00b_level0_row4" class="row_heading level0 row4" >Sentence Type:</th>
#       <td id="T_7d00b_row4_col0" class="data row4 col0" >0.011472</td>
#       <td id="T_7d00b_row4_col1" class="data row4 col1" >0.062917</td>
#       <td id="T_7d00b_row4_col2" class="data row4 col2" >0.024632</td>
#       <td id="T_7d00b_row4_col3" class="data row4 col3" >0.139413</td>
#       <td id="T_7d00b_row4_col4" class="data row4 col4" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %%
grouped= df2.groupby(['Race:','Sentence Type:']).size().unstack()
grouped.plot(kind = "bar", figsize = (20,8))
# Out:
# <AxesSubplot: xlabel='Race:'>

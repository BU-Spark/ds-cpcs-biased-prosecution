# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np

# from google.colab import drive
# drive.mount('/content/drive')

berkshire3_df = pd.read_excel('Berkshire3.xlsx')
berkshire4_df = pd.read_excel('Berkshire4.xlsx')
berkshire3_df.head()
berkshire4_df.head()
# Out:
#    Status       Nmbr Cs  Id Prsn Dfndnt           Offense Dt Court Code  \
# 0  Closed  19-05-103518           24840  1992-02-29 00:00:00       CBDC
# 1  Closed  19-05-103519           24840  1992-02-01 00:00:00       CBDC
# 2  Closed  19-08-104806           24840  2019-07-09 00:00:00       GBDC
# 3  Closed  19-08-104806           24840  2019-07-09 00:00:00       GBDC
# 4  Closed  19-04-103189           24867  2019-04-06 00:00:00       NADC
#
#    Chrg Cnt Chrg Code                                       Chrg Desc  \
# 0         1  266/37/B   LARCENY BY CHECK UNDER $250 c266 §37 & §30(1)
# 1         1  266/37/B   LARCENY BY CHECK UNDER $250 c266 §37 & §30(1)
# 2         1   90/10/A              UNLICENSED OPERATION OF MV c90 §10
# 3         2    90/7/D  EQUIPMENT VIOLATION, MISCELLANEOUS MV * c90 §7
# 4         1  94C/34/D      DRUG, POSSESS CLASS B, SUBSQ.OFF. c94C §34
#
#        Case Type               Crime Type  ... Min Actl Jail Imp Term Unt  \
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np

# from google.colab import drive
# drive.mount('/content/drive')

berkshire3_df = pd.read_excel('Berkshire3.xlsx')
berkshire4_df = pd.read_excel('Berkshire4.xlsx')
berkshire_total = pd.concat([berkshire3_df, berkshire4_df])
#berkshire3_df = pd.read_excel('/content/drive/Shared drives/BU Spark! CS506 - CPCS Team/Berkshire/3. 1.1.10 - 12.31.18 All DAMION excl invest and juvenile.xlsx')
#berkshire4_df = pd.read_excel('/content/drive/Shared drives/BU Spark! CS506 - CPCS Team/Berkshire/4. 1.1.19 - 1.14.22 All DAMION excl invest and juvenile.xlsx')
# berkshire3_df.head()
# berkshire4_df.head()

df = berkshire_total[["Chrg Cnt", "Chrg Desc", "Case Type", "Crime Type", "Race", "Gender", "Disp Type", "Disp Desc", "Sentence Translation"]]

#conversion of string/character values to integers
Ctype = df['Case Type'].value_counts().index.tolist()
i = 0
for i in range(len(Ctype)):
  df['Case Type'].replace(Ctype[i], i, inplace = True)
# df['Case Type']

crime = df['Crime Type'].value_counts().index.tolist()
i = 0
for i in range(len(crime)):
  df['Crime Type'].replace(crime[i], i, inplace = True)

j= 0
race = df['Race'].value_counts().index.tolist()
for j in range(len(race)):
  df['Race'].replace(race[j], j, inplace = True)

k= 0
sentence = df['Sentence Translation'].value_counts().index.tolist()
for k in range(len(sentence)):
  df['Sentence Translation'].replace(sentence[k], k, inplace = True)

k= 0
disptype = df['Disp Type'].value_counts().index.tolist()
for k in range(len(disptype)):
  df['Disp Type'].replace(disptype[k], k, inplace = True)

k =0
gender = df['Gender'].value_counts().index.tolist()
for k in range(len(gender)):
  df['Gender'].replace(gender[k], k, inplace = True)

k =0
desc = df['Disp Desc'].value_counts().index.tolist()
for k in range(len(desc)):
  df['Disp Desc'].replace(desc[k], k, inplace = True)



# correlation = df["Race"].corr(df["Case Type"])
# correlation
# df['Race']
df2 = df[['Race', 'Gender','Case Type','Crime Type' ,'Disp Type', 'Disp Desc', 'Sentence Translation']]
corr = df2.corr()
corr
corr.style.background_gradient(cmap='coolwarm')

#how many are 


# grouped= df2.groupby(['Race','Sentence Translation']).size().unstack()
# grouped.plot(kind = "bar", )
# grouped_count = df2.groupby(['Race','Sentence Translation']).count()
# grouped.plot(kind = "bar")

# races = df2["Race"].count()
# df2.plot(x="Race", y=["Sentence Translation", "Disp Type"], kind="bar", figsize=(9, 8))
# print(grouped)
# print(races)
 
# corr
# Out:
# /var/folders/ks/vzxfw4ks2qqgpbl6l3n_3mkr0000gn/T/ipykernel_7529/3737454399.py:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Case Type'].replace(Ctype[i], i, inplace = True)
# /var/folders/ks/vzxfw4ks2qqgpbl6l3n_3mkr0000gn/T/ipykernel_7529/3737454399.py:29: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Crime Type'].replace(crime[i], i, inplace = True)
# /var/folders/ks/vzxfw4ks2qqgpbl6l3n_3mkr0000gn/T/ipykernel_7529/3737454399.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
#test cell
import pandas as pd
import seaborn as sns
import matplotlib.pylab as plt
import numpy as np

# from google.colab import drive
# drive.mount('/content/drive')

#berkshire3_df = pd.read_excel('/content/drive/Shared drives/BU Spark! CS506 - CPCS Team/Berkshire/3. 1.1.10 - 12.31.18 All DAMION excl invest and juvenile.xlsx')
#berkshire4_df = pd.read_excel('/content/drive/Shared drives/BU Spark! CS506 - CPCS Team/Berkshire/4. 1.1.19 - 1.14.22 All DAMION excl invest and juvenile.xlsx')
df = berkshire3_df[["Chrg Cnt", "Chrg Desc", "Case Type", "Crime Type", "Race", "Gender", "Disp Type", "Disp Desc", "Sentence Translation"]]


# df2 = df[['Race','Case Type']]
# correlation = df["Race"].corr(df["Case Type"])

# correlation 
# corr = df2.corr()

# df2

grouped= df2.groupby(['Race','Sentence Translation']).size().unstack()
# grouped_count= df2.groupby(['Race','Sentence Translation']).value_counts().index.tolist()

# print(grouped_count)

#plot percentage of each group Race/Sentence Translation
grouped = grouped.div(grouped.sum(axis=1), axis=0)
#labeling
#regrouping

#grouped = grouped[['Probation', 'Jail', 'Probation and Jail', 'Probation and Fine', 'Probation and Jail and Fine', 'Jail and Fine', 'Probation and Jail and Community Service', 'Probation and Community Service', 'Jail and Community Service', 'Probation and Jail and Community Service and Fine', 'Probation and Jail and Fine and Community Service', 'Probation and Fine and Community Service', 'Jail and Fine and Community Service', 'Probation and Jail and Fine and Community Service and Probation', 'Probation and Jail and Fine and Community Service and Jail', 'Probation and Jail and Fine and Community Service and Jail and Probation', 'Probation and Jail and Fine and Community Service and Jail and Fine', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine', 'Probation and Jail and Fine and Community Service and Jail and Probation and Community Service', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Probation', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Fine', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation and Fine', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation and Community Service', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation and Fine and Community Service', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation and Fine and Community Service and Probation', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation and Fine and Community']]
grouped.index = ['Black', 'White', 'Hispanic', 'Asian', 'Other', 'Unknown', 'Native American', 'Pacific Islander']
#plot
print(df2)

#labeling legend

#sentence translation values
# ['Probation', 'Jail', 'Probation and Jail', 'Probation and Fine', 'Probation and Jail and Fine', 'Jail and Fine', 'Probation and Jail and Community Service', 'Probation and Community Service', 'Jail and Community Service', 'Probation and Jail and Community Service and Fine', 'Probation and Jail and Fine and Community Service', 'Probation and Fine and Community Service', 'Jail and Fine and Community Service', 'Probation and Jail and Fine and Community Service and Probation', 'Probation and Jail and Fine and Community Service and Jail', 'Probation and Jail and Fine and Community Service and Jail and Probation', 'Probation and Jail and Fine and Community Service and Jail and Fine', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine', 'Probation and Jail and Fine and Community Service and Jail and Probation and Community Service', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Probation', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Fine', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation and Fine', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation and Community Service', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation and Fine and Community Service', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation and Fine and Community Service and Probation', 'Probation and Jail and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail and Probation and Fine and Community Service and Jail']
grouped.plot(kind = "bar", stacked = True, figsize=(9, 8))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In [3], line 34
#      29 grouped = grouped.div(grouped.sum(axis=1), axis=0)
#      30 #labeling
#      31 #regrouping
#      32
# ...

# %%
group_df = berkshire3_df[["Chrg Cnt", "Chrg Desc", "Case Type", "Crime Type", "Race", "Gender", "Disp Type", "Disp Desc", "Sentence Translation"]]
#change all races to white and other
# group_df['Race'] = (group_df['Race'] != "white")

group_df['Race'].replace(
    to_replace=['Black','Asian', 'Hispanic', 'Native American', 'Pacific Islander', 'Unknown'],
    value='Other'
)

grouped2 = group_df.groupby(['Race','Sentence Translation']).size().unstack()
print(grouped2)
# print(grouped2.index)
# print(df['Race'])
grouped2.index = ['White', 'Other']
grouped2 = grouped2.div(grouped2.sum(axis=1), axis=0)
grouped2.plot(kind = "bar", stacked = True, figsize=(9, 8))
# Out:
# Sentence Translation  Committed  Community Service  \
# Race
# A                           NaN                NaN
# B                           1.0                2.0
# C                           NaN                NaN
# EI                          NaN                NaN
# H                           NaN                NaN
# I                           NaN                NaN
# U                           NaN                NaN
# W                          16.0                9.0
#
# Sentence Translation  Continued w/o Change of Plea  Continued w/o Finding  \
# Race
# A                                              8.0                   33.0
# B                                             32.0                 1761.0
# C                                              NaN                    5.0
# EI                                             NaN                    1.0
# H                                              9.0                  386.0
# ...
